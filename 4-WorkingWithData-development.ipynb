# %%
lc = fits.open('kplr006922244-2009322144938_slc.fits')

# %%
lc.info()
# Out:
# Filename: kplr006922244-2009322144938_slc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      58   ()
#   1  LIGHTCURVE    1 BinTableHDU    155   44100R x 20C   [D, E, J, E, E, E, E, E, E, J, D, E, D, E, D, E, D, E, E, E]
#   2  APERTURE      1 ImageHDU        48   (6, 5)   int32

# %%
lightcurve = lc[1]
lightcurve.header
# Out:
# XTENSION= 'BINTABLE'           / marks the beginning of a new HDU
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  100 / length of first array dimension
# NAXIS2  =                44100 / length of second array dimension
# PCOUNT  =                    0 / group parameter count (not used)
# GCOUNT  =                    1 / group count (not used)
# TFIELDS =                   20 / number of table fields
# TTYPE1  = 'TIME    '           / column title: data time stamps
# TFORM1  = 'D       '           / column format: 64-bit floating point
# TUNIT1  = 'BJD - 2454833'      / column units: barycenter corrected JD
# TDISP1  = 'D14.7   '           / column display format
# TTYPE2  = 'TIMECORR'           / column title: barycenter - timeslice correction
# TFORM2  = 'E       '           / column format: 32-bit floating point
# TUNIT2  = 'd       '           / column units: day
# ...

# %%
flux = lightcurve.data.field('PDCSAP_FLUX')

# %%
# %matplotlib notebook
plt.plot(range(len(flux)),flux)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lightcurve.data.columns
# Out:
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 'BJD - 2454833'; disp = 'D14.7'
#     name = 'TIMECORR'; format = 'E'; unit = 'd'; disp = 'E13.6'
#     name = 'CADENCENO'; format = 'J'; disp = 'I10'
#     name = 'SAP_FLUX'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_FLUX_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_BKG'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_BKG_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'PDCSAP_FLUX'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'PDCSAP_FLUX_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_QUALITY'; format = 'J'; disp = 'B16.16'
#     name = 'PSF_CENTR1'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'PSF_CENTR1_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
#     name = 'PSF_CENTR2'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'PSF_CENTR2_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
# ...

# %%
lc = pd.read_csv('hlsp_k2sff_k2_lightcurve_202126852-c00_kepler_v1_llc-default-aper.txt', header=0,
                    names=['Date','Flux','Nan'], dtype={'Date':float,'Flux':float}).loc[1:]
lc
# Out:
#              Date      Flux  Nan
# 1     1939.129885  0.998196  NaN
# 2     1939.150316  0.998491  NaN
# 3     1939.170748  0.998423  NaN
# 4     1939.191179  0.998453  NaN
# 5     1939.211611  0.998510  NaN
# ...           ...       ...  ...
# 1322  1972.106571  1.000704  NaN
# 1323  1972.127003  1.000866  NaN
# 1324  1972.147435  1.000847  NaN
# 1325  1972.167866  1.000933  NaN
# 1326  1972.188298  1.001055  NaN
#
# [1326 rows x 3 columns]

# %%
# %matplotlib notebook
plt.plot(lc['Date'],lc['Flux'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
